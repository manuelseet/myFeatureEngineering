# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import pca_plot

# %%
df = pd.read_csv("wine.csv")
print(df.shape)
df
# Out:
# (178, 14)
#      Cultivar  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0           1    14.23        1.71  2.43               15.6        127
# 1           1    13.20        1.78  2.14               11.2        100
# 2           1    13.16        2.36  2.67               18.6        101
# 3           1    14.37        1.95  2.50               16.8        113
# 4           1    13.24        2.59  2.87               21.0        118
# ..        ...      ...         ...   ...                ...        ...
# 173         3    13.71        5.65  2.45               20.5         95
# 174         3    13.40        3.91  2.48               23.0        102
# 175         3    13.27        4.28  2.26               20.0        120
# 176         3    13.17        2.59  2.37               20.0        120
# 177         3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# 1             2.65        2.76                  0.26             1.28
# 2             2.80        3.24                  0.30             2.81
# 3             3.85        3.49                  0.24             2.18
# 4             2.80        2.69                  0.39             1.82
# ..             ...         ...                   ...              ...
# 173           1.68        0.61                  0.52             1.06
# 174           1.80        0.75                  0.43             1.41
# 175           1.59        0.69                  0.43             1.35
# 176           1.65        0.68                  0.53             1.46
# 177           2.05        0.76                  0.56             1.35
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0               5.64  1.04                          3.92     1065
# 1               4.38  1.05                          3.40     1050
# 2               5.68  1.03                          3.17     1185
# 3               7.80  0.86                          3.45     1480
# 4               4.32  1.04                          2.93      735
# ..               ...   ...                           ...      ...
# 173             7.70  0.64                          1.74      740
# 174             7.30  0.70                          1.56      750
# 175            10.20  0.59                          1.56      835
# 176             9.30  0.60                          1.62      840
# 177             9.20  0.61                          1.60      560
#
# [178 rows x 14 columns]

# %%
sb.set(style='darkgrid')
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(12,8))

sb.kdeplot(data=df, x='Alcalinity of ash', hue='Cultivar', ax=ax[0,0])
sb.kdeplot(data=df, x='Flavanoids', hue='Cultivar', ax=ax[0,1])
sb.kdeplot(data=df, x='Hue', hue='Cultivar', ax=ax[1,0])
sb.kdeplot(data=df, x='Proline', hue='Cultivar', ax=ax[1,1])
# Out:
# <AxesSubplot:xlabel='Proline', ylabel='Density'>

# %%
X = np.array(df.drop("Cultivar", axis = 1))
scaler = StandardScaler()

Xscaled = scaler.fit_transform(X)
Xscaled.shape
# Out:
# (178, 13)

# %%
pca_plot.pca_plot(Xscaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-773bb2af303c> in <module>
# ----> 1 pca_plot.pca_plot(Xscaled)
#
# c:\Users\manue\source\repos\myFeatureEngineering\pca_plot.py in pca_plot(data, n_comp, threshold)
#      34
#      35     evr = myPCA.explained_variance_ratio_
# ---> 36     cumul = pca_cumulative_explained(myPCA)
#      37
#      38     x_axis = ["PC{0}".format(i+1) for i in range(n_comp)]
#
# c:\Users\manue\source\repos\myFeatureEngineering\pca_cumulative_explained.py in pca_cumulative_explained(thispca)
#       3     cumul = []
#       4     curr = 0
# ----> 5     for i in range(len(evr)):
#       6         if i == 0:
#       7             cumul.append(evr[i])
#
# NameError: name 'n_comp' is not defined
